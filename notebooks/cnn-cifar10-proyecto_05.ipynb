# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## **MASTER DATA SCIENCE:** Nuclio
# ## **PROFESORES:** Valentina Borgonovi, Isidre Royo
# ## **ENTREGABLE 4:** Deep Learning - Visión por computador
# ## **ALUMNO:** Simone Solieri

# %% [markdown]
# ##**Proyecto 5** - Resumen
# **Objetivo:** Reducir aún más el overfitting y alncazar una mejor accuracy de test.
#
# **Cambios efectuados:**
# - dropout 0.5
# - Puesto minimo learning rate en 0.00001
#
#  **Resultados**:
# Resultados esperados: Mayor redducion del overfitting, y mejor metrica en test.
#
# Resultados obtenidos: + 3,7 puntos de accuracy en test  ---> 84,9%

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1,
          activation='relu',
          padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(256, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_6 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 965034 (3.68 MB)
# Trainable params: 963370 (3.67 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer= 'Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 32x32 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 18s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset Cifar10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 512
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# # EarlyStopping
earlystop_val_acc = EarlyStopping(monitor='val_accuracy', patience=10)
earlystop_val_loss = EarlyStopping(monitor='val_loss', patience=10)


reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=5, min_lr=0.00001, )

# ModelCheckpoint
checkpoint_path = '/content/drive/MyDrive/Master_Data_Science/Entregables/Entregable_04-Deep_Learning/Models/Model_Checkpoints/Best_accuracy_proyecto_05'
modelcheckpoint_best_acc = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True)

# %%
history = model.fit(x_train_scaled, y_train,
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val),
                    callbacks=[modelcheckpoint_best_acc, reduce_lr_callback, earlystop_val_loss, earlystop_val_acc ])
# Out:
# Epoch 1/300
# 79/79 [==============================] - 27s 181ms/step - loss: 2.2630 - accuracy: 0.3011 - val_loss: 3.3843 - val_accuracy: 0.0952 - lr: 0.0010
# Epoch 2/300
# 79/79 [==============================] - 6s 79ms/step - loss: 1.6466 - accuracy: 0.4193 - val_loss: 3.6601 - val_accuracy: 0.0952 - lr: 0.0010
# Epoch 3/300
# 79/79 [==============================] - 9s 121ms/step - loss: 1.4325 - accuracy: 0.4861 - val_loss: 4.2619 - val_accuracy: 0.1177 - lr: 0.0010
# Epoch 4/300
# 79/79 [==============================] - 10s 129ms/step - loss: 1.2745 - accuracy: 0.5385 - val_loss: 2.8884 - val_accuracy: 0.1959 - lr: 0.0010
# Epoch 5/300
# 79/79 [==============================] - 10s 130ms/step - loss: 1.1606 - accuracy: 0.5805 - val_loss: 2.8259 - val_accuracy: 0.2435 - lr: 0.0010
# Epoch 6/300
# 79/79 [==============================] - 9s 117ms/step - loss: 1.0665 - accuracy: 0.6210 - val_loss: 2.2253 - val_accuracy: 0.3300 - lr: 0.0010
# Epoch 7/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.9924 - accuracy: 0.6474 - val_loss: 1.4922 - val_accuracy: 0.4978 - lr: 0.0010
# Epoch 8/300
# 79/79 [==============================] - 10s 132ms/step - loss: 0.9176 - accuracy: 0.6766 - val_loss: 1.0186 - val_accuracy: 0.6436 - lr: 0.0010
# Epoch 9/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.8736 - accuracy: 0.6891 - val_loss: 0.9028 - val_accuracy: 0.6903 - lr: 0.0010
# Epoch 10/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.8252 - accuracy: 0.7093 - val_loss: 0.9052 - val_accuracy: 0.6948 - lr: 0.0010
# Epoch 11/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.7814 - accuracy: 0.7254 - val_loss: 0.8936 - val_accuracy: 0.6943 - lr: 0.0010
# Epoch 12/300
# 79/79 [==============================] - 9s 117ms/step - loss: 0.7580 - accuracy: 0.7337 - val_loss: 0.8863 - val_accuracy: 0.6993 - lr: 0.0010
# Epoch 13/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.7201 - accuracy: 0.7469 - val_loss: 0.7007 - val_accuracy: 0.7592 - lr: 0.0010
# Epoch 14/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.7036 - accuracy: 0.7527 - val_loss: 0.7169 - val_accuracy: 0.7521 - lr: 0.0010
# Epoch 15/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.6738 - accuracy: 0.7649 - val_loss: 0.7343 - val_accuracy: 0.7497 - lr: 0.0010
# Epoch 16/300
# 79/79 [==============================] - 10s 125ms/step - loss: 0.6553 - accuracy: 0.7690 - val_loss: 0.6146 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 17/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.6385 - accuracy: 0.7753 - val_loss: 0.6817 - val_accuracy: 0.7706 - lr: 0.0010
# Epoch 18/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.6093 - accuracy: 0.7886 - val_loss: 0.6134 - val_accuracy: 0.7867 - lr: 0.0010
# Epoch 19/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.5884 - accuracy: 0.7928 - val_loss: 0.6573 - val_accuracy: 0.7807 - lr: 0.0010
# Epoch 20/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.5726 - accuracy: 0.7989 - val_loss: 0.7981 - val_accuracy: 0.7339 - lr: 0.0010
# Epoch 21/300
# 79/79 [==============================] - 10s 127ms/step - loss: 0.5582 - accuracy: 0.8054 - val_loss: 0.5995 - val_accuracy: 0.7985 - lr: 0.0010
# Epoch 22/300
# 79/79 [==============================] - 7s 83ms/step - loss: 0.5465 - accuracy: 0.8081 - val_loss: 0.6022 - val_accuracy: 0.7911 - lr: 0.0010
# Epoch 23/300
# 79/79 [==============================] - 10s 129ms/step - loss: 0.5331 - accuracy: 0.8126 - val_loss: 0.5536 - val_accuracy: 0.8138 - lr: 0.0010
# Epoch 24/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5079 - accuracy: 0.8228 - val_loss: 0.6078 - val_accuracy: 0.7990 - lr: 0.0010
# Epoch 25/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.4920 - accuracy: 0.8266 - val_loss: 0.5555 - val_accuracy: 0.8134 - lr: 0.0010
# Epoch 26/300
# 79/79 [==============================] - 10s 126ms/step - loss: 0.4783 - accuracy: 0.8317 - val_loss: 0.5533 - val_accuracy: 0.8162 - lr: 0.0010
# Epoch 27/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.4714 - accuracy: 0.8343 - val_loss: 0.5879 - val_accuracy: 0.8068 - lr: 0.0010
# Epoch 28/300
# 79/79 [==============================] - 10s 131ms/step - loss: 0.4577 - accuracy: 0.8395 - val_loss: 0.5036 - val_accuracy: 0.8311 - lr: 0.0010
# Epoch 29/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4425 - accuracy: 0.8453 - val_loss: 0.5382 - val_accuracy: 0.8271 - lr: 0.0010
# Epoch 30/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.4394 - accuracy: 0.8440 - val_loss: 0.6306 - val_accuracy: 0.7957 - lr: 0.0010
# Epoch 31/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4302 - accuracy: 0.8493 - val_loss: 0.5682 - val_accuracy: 0.8128 - lr: 0.0010
# Epoch 32/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.4248 - accuracy: 0.8512 - val_loss: 0.5047 - val_accuracy: 0.8340 - lr: 0.0010
# Epoch 33/300
# 79/79 [==============================] - 11s 134ms/step - loss: 0.4112 - accuracy: 0.8548 - val_loss: 0.5022 - val_accuracy: 0.8347 - lr: 0.0010
# Epoch 34/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3996 - accuracy: 0.8593 - val_loss: 0.5313 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 35/300
# 79/79 [==============================] - 7s 83ms/step - loss: 0.3886 - accuracy: 0.8635 - val_loss: 0.5572 - val_accuracy: 0.8195 - lr: 0.0010
# Epoch 36/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3822 - accuracy: 0.8666 - val_loss: 0.5462 - val_accuracy: 0.8211 - lr: 0.0010
# Epoch 37/300
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3748 - accuracy: 0.8673 - val_loss: 0.5390 - val_accuracy: 0.8267 - lr: 0.0010
# Epoch 38/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3724 - accuracy: 0.8690 - val_loss: 0.5881 - val_accuracy: 0.8103 - lr: 0.0010
# Epoch 39/300
# 79/79 [==============================] - 10s 125ms/step - loss: 0.3178 - accuracy: 0.8867 - val_loss: 0.4624 - val_accuracy: 0.8461 - lr: 1.0000e-04
# Epoch 40/300
# 79/79 [==============================] - 11s 134ms/step - loss: 0.3040 - accuracy: 0.8938 - val_loss: 0.4472 - val_accuracy: 0.8505 - lr: 1.0000e-04
# Epoch 41/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.2962 - accuracy: 0.8960 - val_loss: 0.4526 - val_accuracy: 0.8493 - lr: 1.0000e-04
# Epoch 42/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.2870 - accuracy: 0.9007 - val_loss: 0.4466 - val_accuracy: 0.8521 - lr: 1.0000e-04
# Epoch 43/300
# 79/79 [==============================] - 11s 134ms/step - loss: 0.2875 - accuracy: 0.8979 - val_loss: 0.4390 - val_accuracy: 0.8557 - lr: 1.0000e-04
# Epoch 44/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.2805 - accuracy: 0.9004 - val_loss: 0.4443 - val_accuracy: 0.8545 - lr: 1.0000e-04
# Epoch 45/300
# 79/79 [==============================] - 7s 84ms/step - loss: 0.2752 - accuracy: 0.9031 - val_loss: 0.4462 - val_accuracy: 0.8534 - lr: 1.0000e-04
# Epoch 46/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.2709 - accuracy: 0.9039 - val_loss: 0.4488 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 47/300
# 79/79 [==============================] - 7s 83ms/step - loss: 0.2698 - accuracy: 0.9043 - val_loss: 0.4480 - val_accuracy: 0.8543 - lr: 1.0000e-04
# Epoch 48/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.2663 - accuracy: 0.9058 - val_loss: 0.4592 - val_accuracy: 0.8532 - lr: 1.0000e-04
# Epoch 49/300
# 79/79 [==============================] - 10s 126ms/step - loss: 0.2582 - accuracy: 0.9098 - val_loss: 0.4497 - val_accuracy: 0.8566 - lr: 1.0000e-05
# Epoch 50/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.2627 - accuracy: 0.9085 - val_loss: 0.4469 - val_accuracy: 0.8564 - lr: 1.0000e-05
# Epoch 51/300
# 79/79 [==============================] - 7s 85ms/step - loss: 0.2640 - accuracy: 0.9065 - val_loss: 0.4462 - val_accuracy: 0.8565 - lr: 1.0000e-05
# Epoch 52/300
# 79/79 [==============================] - 10s 127ms/step - loss: 0.2583 - accuracy: 0.9082 - val_loss: 0.4470 - val_accuracy: 0.8570 - lr: 1.0000e-05
# Epoch 53/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.2609 - accuracy: 0.9081 - val_loss: 0.4488 - val_accuracy: 0.8553 - lr: 1.0000e-05

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:24.766500

# %% [markdown]
# Cargo el mejor model que he guardado con el ModelCheckpoint.

# %%
model = ks.models.load_model(checkpoint_path)

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 84.940

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Entregables/Entregable_04-Deep_Learning/Models/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_model_05.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
