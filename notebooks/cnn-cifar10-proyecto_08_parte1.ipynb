# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## **MASTER DATA SCIENCE:** Nuclio
# ## **PROFESORES:** Valentina Borgonovi, Isidre Royo
# ## **ENTREGABLE 4:** Deep Learning - Visión por computador
# ## **ALUMNO:** Simone Solieri

# %% [markdown]
# ## **Proyecto 8 parte 1** - Resumen
#
# Objetivo: Construir un modelo solido con accuracy minima de test del 85%, pero con suficiente complejidad para sacar provecho de un succesivo data augmentation.
#
# Implementaciones:
# dropout 0.5
# Aumentada complejidad de la parte de clasificacion: 1024-1024-512
#
#
#
# **Resultados:**
#
# 86,2% accuracy de test.
#
# Esta arquitectura es mejor que la del principio con un sola capa densa de clasificación, porqué sin aplicar weight decay alcanza
# practicamente la misma accuracy.
#
# Puedo probar data augmentation sobre esta arquitectura.

# %%
(94.7-67.5)/67.5*100
# Out:
# 40.296296296296305

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',padding='same',
          input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1,
          activation='relu',padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(1024, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (Batch  (None, 32, 32, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_6 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  batch_normalization_7 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_8 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  batch_normalization_9 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 7525194 (28.71 MB)
# Trainable params: 7517770 (28.68 MB)
# Non-trainable params: 7424 (29.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 32x32 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset Cifar10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 512
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# # EarlyStopping
earlystop_val_acc = EarlyStopping(monitor= 'val_accuracy', patience=10)
earlystop_val_loss = EarlyStopping(monitor='val_loss', patience=10)
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=5, min_lr=0.00001, )

# ModelCheckpoint
checkpoint_path = '/content/drive/MyDrive/Master_Data_Science/Entregables/Entregable_04-Deep_Learning/Models/Model_Checkpoints/Best_accuracy_proyecto_08_parte1'
modelcheckpoint_best_acc = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True)

# %%
history = model.fit(x_train_scaled, y_train,
                    epochs=150,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val),
                    callbacks=[modelcheckpoint_best_acc, reduce_lr_callback, earlystop_val_loss, earlystop_val_acc])
# Out:
# Epoch 1/150
# 79/79 [==============================] - 42s 316ms/step - loss: 2.3928 - accuracy: 0.2677 - val_loss: 6.4229 - val_accuracy: 0.0997 - lr: 0.0010
# Epoch 2/150
# 79/79 [==============================] - 14s 174ms/step - loss: 1.7052 - accuracy: 0.3976 - val_loss: 3.9985 - val_accuracy: 0.0973 - lr: 0.0010
# Epoch 3/150
# 79/79 [==============================] - 14s 175ms/step - loss: 1.4634 - accuracy: 0.4785 - val_loss: 3.7043 - val_accuracy: 0.0979 - lr: 0.0010
# Epoch 4/150
# 79/79 [==============================] - 17s 222ms/step - loss: 1.2940 - accuracy: 0.5510 - val_loss: 2.9041 - val_accuracy: 0.1781 - lr: 0.0010
# Epoch 5/150
# 79/79 [==============================] - 18s 227ms/step - loss: 1.1448 - accuracy: 0.6011 - val_loss: 2.7855 - val_accuracy: 0.2259 - lr: 0.0010
# Epoch 6/150
# 79/79 [==============================] - 19s 244ms/step - loss: 1.0371 - accuracy: 0.6381 - val_loss: 1.9592 - val_accuracy: 0.3686 - lr: 0.0010
# Epoch 7/150
# 79/79 [==============================] - 17s 221ms/step - loss: 0.9604 - accuracy: 0.6668 - val_loss: 1.2725 - val_accuracy: 0.5521 - lr: 0.0010
# Epoch 8/150
# 79/79 [==============================] - 19s 240ms/step - loss: 0.9006 - accuracy: 0.6890 - val_loss: 1.0925 - val_accuracy: 0.6195 - lr: 0.0010
# Epoch 9/150
# 79/79 [==============================] - 18s 231ms/step - loss: 0.8213 - accuracy: 0.7137 - val_loss: 0.8693 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 10/150
# 79/79 [==============================] - 18s 225ms/step - loss: 0.7578 - accuracy: 0.7347 - val_loss: 0.6861 - val_accuracy: 0.7611 - lr: 0.0010
# Epoch 11/150
# 79/79 [==============================] - 14s 172ms/step - loss: 0.7012 - accuracy: 0.7540 - val_loss: 0.7168 - val_accuracy: 0.7594 - lr: 0.0010
# Epoch 12/150
# 79/79 [==============================] - 19s 244ms/step - loss: 0.6573 - accuracy: 0.7692 - val_loss: 0.6776 - val_accuracy: 0.7682 - lr: 0.0010
# Epoch 13/150
# 79/79 [==============================] - 18s 233ms/step - loss: 0.6065 - accuracy: 0.7897 - val_loss: 0.6401 - val_accuracy: 0.7852 - lr: 0.0010
# Epoch 14/150
# 79/79 [==============================] - 19s 239ms/step - loss: 0.5796 - accuracy: 0.7962 - val_loss: 0.6181 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 15/150
# 79/79 [==============================] - 19s 235ms/step - loss: 0.5448 - accuracy: 0.8113 - val_loss: 0.5878 - val_accuracy: 0.8012 - lr: 0.0010
# Epoch 16/150
# 79/79 [==============================] - 14s 178ms/step - loss: 0.5177 - accuracy: 0.8188 - val_loss: 0.7439 - val_accuracy: 0.7582 - lr: 0.0010
# Epoch 17/150
# 79/79 [==============================] - 18s 228ms/step - loss: 0.4797 - accuracy: 0.8325 - val_loss: 0.5407 - val_accuracy: 0.8221 - lr: 0.0010
# Epoch 18/150
# 79/79 [==============================] - 14s 179ms/step - loss: 0.4569 - accuracy: 0.8419 - val_loss: 0.6798 - val_accuracy: 0.7842 - lr: 0.0010
# Epoch 19/150
# 79/79 [==============================] - 14s 174ms/step - loss: 0.4311 - accuracy: 0.8500 - val_loss: 0.6191 - val_accuracy: 0.8052 - lr: 0.0010
# Epoch 20/150
# 79/79 [==============================] - 14s 177ms/step - loss: 0.4094 - accuracy: 0.8572 - val_loss: 0.6231 - val_accuracy: 0.8032 - lr: 0.0010
# Epoch 21/150
# 79/79 [==============================] - 14s 176ms/step - loss: 0.3875 - accuracy: 0.8669 - val_loss: 0.6503 - val_accuracy: 0.8002 - lr: 0.0010
# Epoch 22/150
# 79/79 [==============================] - 18s 229ms/step - loss: 0.3626 - accuracy: 0.8745 - val_loss: 0.5353 - val_accuracy: 0.8321 - lr: 0.0010
# Epoch 23/150
# 79/79 [==============================] - 14s 181ms/step - loss: 0.3399 - accuracy: 0.8808 - val_loss: 0.5952 - val_accuracy: 0.8223 - lr: 0.0010
# Epoch 24/150
# 79/79 [==============================] - 14s 181ms/step - loss: 0.3389 - accuracy: 0.8822 - val_loss: 0.6316 - val_accuracy: 0.8102 - lr: 0.0010
# Epoch 25/150
# 79/79 [==============================] - 14s 174ms/step - loss: 0.3253 - accuracy: 0.8868 - val_loss: 0.5712 - val_accuracy: 0.8287 - lr: 0.0010
# Epoch 26/150
# 79/79 [==============================] - 14s 182ms/step - loss: 0.3005 - accuracy: 0.8954 - val_loss: 0.6631 - val_accuracy: 0.8106 - lr: 0.0010
# Epoch 27/150
# 79/79 [==============================] - 14s 174ms/step - loss: 0.2770 - accuracy: 0.9039 - val_loss: 0.6468 - val_accuracy: 0.8202 - lr: 0.0010
# Epoch 28/150
# 79/79 [==============================] - 18s 232ms/step - loss: 0.2170 - accuracy: 0.9251 - val_loss: 0.4628 - val_accuracy: 0.8608 - lr: 1.0000e-04
# Epoch 29/150
# 79/79 [==============================] - 19s 239ms/step - loss: 0.1949 - accuracy: 0.9318 - val_loss: 0.4575 - val_accuracy: 0.8616 - lr: 1.0000e-04
# Epoch 30/150
# 79/79 [==============================] - 14s 182ms/step - loss: 0.1789 - accuracy: 0.9381 - val_loss: 0.4628 - val_accuracy: 0.8606 - lr: 1.0000e-04
# Epoch 31/150
# 79/79 [==============================] - 19s 237ms/step - loss: 0.1673 - accuracy: 0.9421 - val_loss: 0.4648 - val_accuracy: 0.8637 - lr: 1.0000e-04
# Epoch 32/150
# 79/79 [==============================] - 14s 174ms/step - loss: 0.1602 - accuracy: 0.9449 - val_loss: 0.4697 - val_accuracy: 0.8621 - lr: 1.0000e-04
# Epoch 33/150
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1559 - accuracy: 0.9460 - val_loss: 0.4641 - val_accuracy: 0.8665 - lr: 1.0000e-04
# Epoch 34/150
# 79/79 [==============================] - 20s 247ms/step - loss: 0.1534 - accuracy: 0.9467 - val_loss: 0.4672 - val_accuracy: 0.8679 - lr: 1.0000e-04
# Epoch 35/150
# 79/79 [==============================] - 19s 241ms/step - loss: 0.1463 - accuracy: 0.9503 - val_loss: 0.4634 - val_accuracy: 0.8681 - lr: 1.0000e-05
# Epoch 36/150
# 79/79 [==============================] - 14s 183ms/step - loss: 0.1399 - accuracy: 0.9515 - val_loss: 0.4638 - val_accuracy: 0.8679 - lr: 1.0000e-05
# Epoch 37/150
# 79/79 [==============================] - 14s 182ms/step - loss: 0.1397 - accuracy: 0.9507 - val_loss: 0.4645 - val_accuracy: 0.8681 - lr: 1.0000e-05
# Epoch 38/150
# 79/79 [==============================] - 14s 182ms/step - loss: 0.1378 - accuracy: 0.9516 - val_loss: 0.4649 - val_accuracy: 0.8679 - lr: 1.0000e-05
# Epoch 39/150
# 79/79 [==============================] - 14s 181ms/step - loss: 0.1384 - accuracy: 0.9522 - val_loss: 0.4657 - val_accuracy: 0.8674 - lr: 1.0000e-05

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:11:02.248051

# %% [markdown]
# Cargo el mejor model que he guardado con el ModelCheckpoint.

# %%
model = ks.models.load_model(checkpoint_path)

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 86.200

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Entregables/Entregable_04-Deep_Learning/Models/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_model_08_parte1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
