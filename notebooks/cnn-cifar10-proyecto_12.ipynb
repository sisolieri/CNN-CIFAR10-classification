# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## **MASTER DATA SCIENCE:** Nuclio
# ## **PROFESORES:** Valentina Borgonovi, Isidre Royo
# ## **ENTREGABLE 4:** Deep Learning - Visión por computador
# ## **ALUMNO:** Simone Solieri

# %% [markdown]
# ## **Proyecto 12** - Resumen
#
# Objetivo: Obtner un modelo con almenos el 90% de accuracy
#
# Implementaciones:
# Transfer learning con VGG-16 + Data augmentation. Uso solamente los primeros 3 bloques de cnvoluciones de VGG-16, que son los que sacan las features más generales.
#
#
# **Resultados:**

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD
from keras.regularizers import l2

from keras.applications import vgg16
from keras.models import Model, load_model

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
import random

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
vgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(32,32,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
output = vgg.get_layer('block3_pool').output
new_output_layer = ks.layers.Conv2D(512, (3, 3), strides=1, activation='relu', padding='same')(output)
vgg_model = Model(vgg.input, new_output_layer)

# %%
vgg_model.trainable
# Out:
# True

# %%
entrenable = False

for layer in vgg_model.layers:
  if layer.name == 'block3_conv1':
    entrenable = True
  layer.trainable = entrenable

# %%
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  conv2d (Conv2D)             (None, 4, 4, 512)         1180160
#
# =================================================================
# Total params: 2915648 (11.12 MB)
# Trainable params: 2655488 (10.13 MB)
# Non-trainable params: 260160 (1016.25 KB)
# _________________________________________________________________

# %%
pd.set_option('max_colwidth', None)
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                         Layer Type  \
# 0               <keras.src.engine.input_layer.InputLayer object at 0x7da15c11a920>
# 1          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8c3e2c0>
# 2          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8c3ea40>
# 3   <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7da0c8c3e620>
# 4          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8c3ec50>
# 5          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8c3f7f0>
# 6   <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7da0c8391570>
# 7          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8391de0>
# 8          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8392500>
# 9          <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da0c8393010>
# 10  <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7da0c83ac0d0>
# 11         <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7da15c135c00>
#
#       Layer Name  Layer Trainable
# 0        input_1            False
# 1   block1_conv1            False
# 2   block1_conv2            False
# 3    block1_pool            False
# 4   block2_conv1            False
# 5   block2_conv2            False
# 6    block2_pool            False
# 7   block3_conv1             True
# 8   block3_conv2             True
# 9   block3_conv3             True
# 10   block3_pool             True
# 11        conv2d             True

# %%
model = ks.Sequential()

model.add(vgg_model)
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(512, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(1024, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(1024, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (Functional)          (None, 4, 4, 512)         2915648
#
#  batch_normalization (Batch  (None, 4, 4, 512)         2048
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  batch_normalization_1 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  dropout (Dropout)           (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  batch_normalization_2 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_3 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 15258954 (58.21 MB)
# Trainable params: 14991626 (57.19 MB)
# Non-trainable params: 267328 (1.02 MB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer= Adam(learning_rate=0.01),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 32x32 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset Cifar10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train_scaled: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test_scaled: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation_scaled: X=%s, y=%s\n' % (x_val_scaled.shape, y_val.shape))

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train_scaled: X=(40000, 32, 32, 3), y=(40000,)
# Test_scaled: X=(10000, 32, 32, 3), y=(10000,)
# Validation_scaled: X=(10000, 32, 32, 3), y=(10000,)
#
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Exploremos los datos

# %%
df_train = pd.DataFrame(y_train, columns=['category'])
df_train['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# Hay 4000 imagenes para cada categoria.

# %% [markdown]
# ## 6. Montamos el generador de imagenes

# %% [markdown]
# **De entrenamiento**
#
# Aquí incluiremos nuestra parte de generación de imagenes (con código de partida)

# %%
batch_size_train = 512

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=20,
    height_shift_range=0.1,
    width_shift_range=0.1,
    fill_mode='nearest',
    # Definamos las transformaciones
    )

train_generator = train_datagen.flow(
    x_train,  # Aquí hay que usar datos NO re-escalados... de ahi que no usemos x_train_rescaled!
    y_train,
    batch_size=batch_size_train
)

# %%
40000//512
# Out:
# 78

# %%
512/4
# Out:
# 128.0

# %% [markdown]
# **De validacion (test no lo necesita)**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
batch_size_val = 128

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=batch_size_val
)

# %% [markdown]
# ## 7. Veamos que pinta tiene el generador de datos
#
# A rellenar para ver que nos da el generador de imagenes nuevas

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 20):
    plt.subplot(5, 4, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        plt.title(cifar10_labels[Y[0]])
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 512
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# # EarlyStopping
earlystop_val_acc = EarlyStopping(monitor= 'val_accuracy', patience=30)
earlystop_val_loss = EarlyStopping(monitor='val_loss', patience=30)
reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=20, min_lr=1e-5, )

# ModelCheckpoint
checkpoint_path = '/content/drive/MyDrive/Master_Data_Science/Entregables/Entregable_04-Deep_Learning/Models/Model_Checkpoints/Best_accuracy_proyecto_12'
modelcheckpoint_best_acc = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True)

# %%
history = model.fit(
        train_generator,
        steps_per_epoch= 40000 // batch_size_train,
        epochs=200,
        validation_data=validation_generator,
        validation_steps=10000 // batch_size_val,
        callbacks=[modelcheckpoint_best_acc, reduce_lr_callback, earlystop_val_loss, earlystop_val_acc ])
# Out:
# Epoch 1/200
# 78/78 [==============================] - 50s 430ms/step - loss: 2.3734 - accuracy: 0.1920 - val_loss: 87.5284 - val_accuracy: 0.1013 - lr: 0.0100
# Epoch 2/200
# 78/78 [==============================] - 29s 371ms/step - loss: 1.9231 - accuracy: 0.2722 - val_loss: 3.8600 - val_accuracy: 0.1252 - lr: 0.0100
# Epoch 3/200
# 78/78 [==============================] - 26s 328ms/step - loss: 1.7176 - accuracy: 0.3507 - val_loss: 41.3411 - val_accuracy: 0.0998 - lr: 0.0100
# Epoch 4/200
# 78/78 [==============================] - 30s 381ms/step - loss: 1.5548 - accuracy: 0.4105 - val_loss: 7.7367 - val_accuracy: 0.1432 - lr: 0.0100
# Epoch 5/200
# 78/78 [==============================] - 30s 388ms/step - loss: 1.4745 - accuracy: 0.4494 - val_loss: 5.9210 - val_accuracy: 0.1876 - lr: 0.0100
# Epoch 6/200
# 78/78 [==============================] - 26s 329ms/step - loss: 1.3170 - accuracy: 0.5116 - val_loss: 5.2040 - val_accuracy: 0.1495 - lr: 0.0100
# Epoch 7/200
# 78/78 [==============================] - 29s 375ms/step - loss: 1.2467 - accuracy: 0.5413 - val_loss: 2.1681 - val_accuracy: 0.3364 - lr: 0.0100
# Epoch 8/200
# 78/78 [==============================] - 26s 333ms/step - loss: 1.3049 - accuracy: 0.5242 - val_loss: 30.2618 - val_accuracy: 0.1073 - lr: 0.0100
# Epoch 9/200
# 78/78 [==============================] - 28s 363ms/step - loss: 1.3219 - accuracy: 0.5093 - val_loss: 1.9125 - val_accuracy: 0.3796 - lr: 0.0100
# Epoch 10/200
# 78/78 [==============================] - 25s 326ms/step - loss: 1.1831 - accuracy: 0.5689 - val_loss: 4.9598 - val_accuracy: 0.1570 - lr: 0.0100
# Epoch 11/200
# 78/78 [==============================] - 25s 320ms/step - loss: 1.1231 - accuracy: 0.5942 - val_loss: 6.5737 - val_accuracy: 0.1743 - lr: 0.0100
# Epoch 12/200
# 78/78 [==============================] - 29s 372ms/step - loss: 1.0668 - accuracy: 0.6192 - val_loss: 1.8796 - val_accuracy: 0.4582 - lr: 0.0100
# Epoch 13/200
# 78/78 [==============================] - 29s 373ms/step - loss: 1.0406 - accuracy: 0.6282 - val_loss: 1.1215 - val_accuracy: 0.6217 - lr: 0.0100
# Epoch 14/200
# 78/78 [==============================] - 26s 329ms/step - loss: 1.0033 - accuracy: 0.6431 - val_loss: 1.6356 - val_accuracy: 0.5479 - lr: 0.0100
# Epoch 15/200
# 78/78 [==============================] - 24s 307ms/step - loss: 0.9734 - accuracy: 0.6538 - val_loss: 1.4232 - val_accuracy: 0.5761 - lr: 0.0100
# Epoch 16/200
# 78/78 [==============================] - 30s 383ms/step - loss: 0.9401 - accuracy: 0.6682 - val_loss: 0.9349 - val_accuracy: 0.6805 - lr: 0.0100
# Epoch 17/200
# 78/78 [==============================] - 27s 345ms/step - loss: 0.9300 - accuracy: 0.6710 - val_loss: 1.1356 - val_accuracy: 0.6396 - lr: 0.0100
# Epoch 18/200
# 78/78 [==============================] - 25s 323ms/step - loss: 0.9131 - accuracy: 0.6781 - val_loss: 1.5608 - val_accuracy: 0.5569 - lr: 0.0100
# Epoch 19/200
# 78/78 [==============================] - 26s 331ms/step - loss: 0.8823 - accuracy: 0.6895 - val_loss: 1.3069 - val_accuracy: 0.6188 - lr: 0.0100
# Epoch 20/200
# 78/78 [==============================] - 29s 369ms/step - loss: 0.8760 - accuracy: 0.6911 - val_loss: 0.9749 - val_accuracy: 0.6883 - lr: 0.0100
# Epoch 21/200
# 78/78 [==============================] - 26s 334ms/step - loss: 0.8557 - accuracy: 0.7030 - val_loss: 1.2287 - val_accuracy: 0.6319 - lr: 0.0100
# Epoch 22/200
# 78/78 [==============================] - 26s 328ms/step - loss: 0.8316 - accuracy: 0.7082 - val_loss: 1.4006 - val_accuracy: 0.6092 - lr: 0.0100
# Epoch 23/200
# 78/78 [==============================] - 29s 374ms/step - loss: 0.8118 - accuracy: 0.7154 - val_loss: 0.9929 - val_accuracy: 0.6894 - lr: 0.0100
# Epoch 24/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.8034 - accuracy: 0.7189 - val_loss: 1.0663 - val_accuracy: 0.6608 - lr: 0.0100
# Epoch 25/200
# 78/78 [==============================] - 29s 373ms/step - loss: 0.7859 - accuracy: 0.7276 - val_loss: 0.9461 - val_accuracy: 0.7114 - lr: 0.0100
# Epoch 26/200
# 78/78 [==============================] - 30s 385ms/step - loss: 0.7661 - accuracy: 0.7356 - val_loss: 0.8392 - val_accuracy: 0.7359 - lr: 0.0100
# Epoch 27/200
# 78/78 [==============================] - 26s 339ms/step - loss: 0.7630 - accuracy: 0.7363 - val_loss: 1.1076 - val_accuracy: 0.7199 - lr: 0.0100
# Epoch 28/200
# 78/78 [==============================] - 26s 328ms/step - loss: 0.7567 - accuracy: 0.7375 - val_loss: 1.2419 - val_accuracy: 0.6467 - lr: 0.0100
# Epoch 29/200
# 78/78 [==============================] - 26s 327ms/step - loss: 0.7393 - accuracy: 0.7454 - val_loss: 0.9500 - val_accuracy: 0.7082 - lr: 0.0100
# Epoch 30/200
# 78/78 [==============================] - 26s 334ms/step - loss: 0.7309 - accuracy: 0.7440 - val_loss: 2.5895 - val_accuracy: 0.7033 - lr: 0.0100
# Epoch 31/200
# 78/78 [==============================] - 25s 325ms/step - loss: 0.7188 - accuracy: 0.7517 - val_loss: 1.1277 - val_accuracy: 0.6831 - lr: 0.0100
# Epoch 32/200
# 78/78 [==============================] - 29s 371ms/step - loss: 0.7148 - accuracy: 0.7526 - val_loss: 0.7655 - val_accuracy: 0.7454 - lr: 0.0100
# Epoch 33/200
# 78/78 [==============================] - 27s 350ms/step - loss: 0.6940 - accuracy: 0.7593 - val_loss: 0.8883 - val_accuracy: 0.7202 - lr: 0.0100
# Epoch 34/200
# 78/78 [==============================] - 25s 326ms/step - loss: 0.6924 - accuracy: 0.7586 - val_loss: 1.0205 - val_accuracy: 0.7164 - lr: 0.0100
# Epoch 35/200
# 78/78 [==============================] - 26s 331ms/step - loss: 0.6939 - accuracy: 0.7600 - val_loss: 0.7800 - val_accuracy: 0.7448 - lr: 0.0100
# Epoch 36/200
# 78/78 [==============================] - 25s 324ms/step - loss: 0.6596 - accuracy: 0.7723 - val_loss: 0.9514 - val_accuracy: 0.7150 - lr: 0.0100
# Epoch 37/200
# 78/78 [==============================] - 30s 376ms/step - loss: 0.6707 - accuracy: 0.7705 - val_loss: 0.8858 - val_accuracy: 0.7487 - lr: 0.0100
# Epoch 38/200
# 78/78 [==============================] - 26s 339ms/step - loss: 0.6573 - accuracy: 0.7725 - val_loss: 0.8866 - val_accuracy: 0.7314 - lr: 0.0100
# Epoch 39/200
# 78/78 [==============================] - 25s 317ms/step - loss: 0.6377 - accuracy: 0.7788 - val_loss: 1.0695 - val_accuracy: 0.7001 - lr: 0.0100
# Epoch 40/200
# 78/78 [==============================] - 29s 375ms/step - loss: 0.6309 - accuracy: 0.7822 - val_loss: 0.6942 - val_accuracy: 0.7770 - lr: 0.0100
# Epoch 41/200
# 78/78 [==============================] - 30s 388ms/step - loss: 0.6266 - accuracy: 0.7848 - val_loss: 0.7126 - val_accuracy: 0.7855 - lr: 0.0100
# Epoch 42/200
# 78/78 [==============================] - 26s 335ms/step - loss: 0.6213 - accuracy: 0.7859 - val_loss: 0.9195 - val_accuracy: 0.7223 - lr: 0.0100
# Epoch 43/200
# 78/78 [==============================] - 27s 342ms/step - loss: 0.6034 - accuracy: 0.7921 - val_loss: 0.9927 - val_accuracy: 0.7023 - lr: 0.0100
# Epoch 44/200
# 78/78 [==============================] - 27s 341ms/step - loss: 0.5944 - accuracy: 0.7968 - val_loss: 1.1631 - val_accuracy: 0.7002 - lr: 0.0100
# Epoch 45/200
# 78/78 [==============================] - 26s 338ms/step - loss: 0.5854 - accuracy: 0.7980 - val_loss: 0.8069 - val_accuracy: 0.7464 - lr: 0.0100
# Epoch 46/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.5808 - accuracy: 0.7986 - val_loss: 0.8302 - val_accuracy: 0.7361 - lr: 0.0100
# Epoch 47/200
# 78/78 [==============================] - 26s 333ms/step - loss: 0.5889 - accuracy: 0.7965 - val_loss: 0.7026 - val_accuracy: 0.7814 - lr: 0.0100
# Epoch 48/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.5686 - accuracy: 0.8046 - val_loss: 0.8198 - val_accuracy: 0.7625 - lr: 0.0100
# Epoch 49/200
# 78/78 [==============================] - 30s 379ms/step - loss: 0.5649 - accuracy: 0.8054 - val_loss: 0.7177 - val_accuracy: 0.8073 - lr: 0.0100
# Epoch 50/200
# 78/78 [==============================] - 27s 341ms/step - loss: 0.5535 - accuracy: 0.8096 - val_loss: 0.7850 - val_accuracy: 0.7681 - lr: 0.0100
# Epoch 51/200
# 78/78 [==============================] - 26s 333ms/step - loss: 0.5545 - accuracy: 0.8101 - val_loss: 0.6621 - val_accuracy: 0.7952 - lr: 0.0100
# Epoch 52/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.5364 - accuracy: 0.8144 - val_loss: 0.6778 - val_accuracy: 0.7939 - lr: 0.0100
# Epoch 53/200
# 78/78 [==============================] - 27s 345ms/step - loss: 0.5285 - accuracy: 0.8187 - val_loss: 0.7777 - val_accuracy: 0.7822 - lr: 0.0100
# Epoch 54/200
# 78/78 [==============================] - 25s 324ms/step - loss: 0.5361 - accuracy: 0.8157 - val_loss: 0.8029 - val_accuracy: 0.7795 - lr: 0.0100
# Epoch 55/200
# 78/78 [==============================] - 26s 338ms/step - loss: 0.5195 - accuracy: 0.8222 - val_loss: 0.8771 - val_accuracy: 0.7519 - lr: 0.0100
# Epoch 56/200
# 78/78 [==============================] - 32s 405ms/step - loss: 0.5093 - accuracy: 0.8258 - val_loss: 0.6077 - val_accuracy: 0.8121 - lr: 0.0100
# Epoch 57/200
# 78/78 [==============================] - 27s 347ms/step - loss: 0.5144 - accuracy: 0.8246 - val_loss: 0.6876 - val_accuracy: 0.7927 - lr: 0.0100
# Epoch 58/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.4860 - accuracy: 0.8326 - val_loss: 1.1033 - val_accuracy: 0.7654 - lr: 0.0100
# Epoch 59/200
# 78/78 [==============================] - 27s 341ms/step - loss: 0.5016 - accuracy: 0.8284 - val_loss: 0.7670 - val_accuracy: 0.7908 - lr: 0.0100
# Epoch 60/200
# 78/78 [==============================] - 27s 343ms/step - loss: 0.4938 - accuracy: 0.8305 - val_loss: 0.6599 - val_accuracy: 0.7981 - lr: 0.0100
# Epoch 61/200
# 78/78 [==============================] - 30s 385ms/step - loss: 0.4748 - accuracy: 0.8381 - val_loss: 0.5951 - val_accuracy: 0.8161 - lr: 0.0100
# Epoch 62/200
# 78/78 [==============================] - 26s 338ms/step - loss: 0.4988 - accuracy: 0.8297 - val_loss: 0.5867 - val_accuracy: 0.8151 - lr: 0.0100
# Epoch 63/200
# 78/78 [==============================] - 27s 347ms/step - loss: 0.4658 - accuracy: 0.8400 - val_loss: 0.7768 - val_accuracy: 0.7841 - lr: 0.0100
# Epoch 64/200
# 78/78 [==============================] - 27s 347ms/step - loss: 0.4625 - accuracy: 0.8424 - val_loss: 0.6251 - val_accuracy: 0.8125 - lr: 0.0100
# Epoch 65/200
# 78/78 [==============================] - 27s 344ms/step - loss: 0.4622 - accuracy: 0.8406 - val_loss: 0.5931 - val_accuracy: 0.8123 - lr: 0.0100
# Epoch 66/200
# 78/78 [==============================] - 31s 399ms/step - loss: 0.4538 - accuracy: 0.8440 - val_loss: 0.5270 - val_accuracy: 0.8288 - lr: 0.0100
# Epoch 67/200
# 78/78 [==============================] - 27s 352ms/step - loss: 0.4596 - accuracy: 0.8437 - val_loss: 0.7425 - val_accuracy: 0.8045 - lr: 0.0100
# Epoch 68/200
# 78/78 [==============================] - 26s 339ms/step - loss: 0.4507 - accuracy: 0.8473 - val_loss: 0.6523 - val_accuracy: 0.8089 - lr: 0.0100
# Epoch 69/200
# 78/78 [==============================] - 30s 386ms/step - loss: 0.4476 - accuracy: 0.8484 - val_loss: 0.5360 - val_accuracy: 0.8305 - lr: 0.0100
# Epoch 70/200
# 78/78 [==============================] - 28s 353ms/step - loss: 0.4296 - accuracy: 0.8526 - val_loss: 0.6012 - val_accuracy: 0.8132 - lr: 0.0100
# Epoch 71/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.4427 - accuracy: 0.8499 - val_loss: 0.5656 - val_accuracy: 0.8195 - lr: 0.0100
# Epoch 72/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.4202 - accuracy: 0.8566 - val_loss: 0.7167 - val_accuracy: 0.7997 - lr: 0.0100
# Epoch 73/200
# 78/78 [==============================] - 27s 343ms/step - loss: 0.4211 - accuracy: 0.8559 - val_loss: 0.5635 - val_accuracy: 0.8287 - lr: 0.0100
# Epoch 74/200
# 78/78 [==============================] - 27s 342ms/step - loss: 0.4093 - accuracy: 0.8594 - val_loss: 0.6385 - val_accuracy: 0.8072 - lr: 0.0100
# Epoch 75/200
# 78/78 [==============================] - 27s 343ms/step - loss: 0.4043 - accuracy: 0.8626 - val_loss: 0.7351 - val_accuracy: 0.7997 - lr: 0.0100
# Epoch 76/200
# 78/78 [==============================] - 25s 325ms/step - loss: 0.4102 - accuracy: 0.8609 - val_loss: 0.6771 - val_accuracy: 0.8115 - lr: 0.0100
# Epoch 77/200
# 78/78 [==============================] - 30s 383ms/step - loss: 0.4035 - accuracy: 0.8610 - val_loss: 0.5767 - val_accuracy: 0.8366 - lr: 0.0100
# Epoch 78/200
# 78/78 [==============================] - 27s 342ms/step - loss: 0.3904 - accuracy: 0.8659 - val_loss: 0.6559 - val_accuracy: 0.8045 - lr: 0.0100
# Epoch 79/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.3867 - accuracy: 0.8694 - val_loss: 0.6146 - val_accuracy: 0.8192 - lr: 0.0100
# Epoch 80/200
# 78/78 [==============================] - 25s 319ms/step - loss: 0.3780 - accuracy: 0.8699 - val_loss: 0.5520 - val_accuracy: 0.8333 - lr: 0.0100
# Epoch 81/200
# 78/78 [==============================] - 26s 328ms/step - loss: 0.3850 - accuracy: 0.8672 - val_loss: 0.6353 - val_accuracy: 0.8175 - lr: 0.0100
# Epoch 82/200
# 78/78 [==============================] - 26s 330ms/step - loss: 0.3786 - accuracy: 0.8711 - val_loss: 0.6944 - val_accuracy: 0.8041 - lr: 0.0100
# Epoch 83/200
# 78/78 [==============================] - 24s 311ms/step - loss: 0.3757 - accuracy: 0.8716 - val_loss: 0.6118 - val_accuracy: 0.8208 - lr: 0.0100
# Epoch 84/200
# 78/78 [==============================] - 29s 376ms/step - loss: 0.3694 - accuracy: 0.8750 - val_loss: 0.5298 - val_accuracy: 0.8372 - lr: 0.0100
# Epoch 85/200
# 78/78 [==============================] - 25s 323ms/step - loss: 0.3803 - accuracy: 0.8707 - val_loss: 0.7243 - val_accuracy: 0.8183 - lr: 0.0100
# Epoch 86/200
# 78/78 [==============================] - 29s 375ms/step - loss: 0.3664 - accuracy: 0.8753 - val_loss: 0.5164 - val_accuracy: 0.8425 - lr: 0.0100
# Epoch 87/200
# 78/78 [==============================] - 26s 339ms/step - loss: 0.3530 - accuracy: 0.8805 - val_loss: 0.7046 - val_accuracy: 0.8222 - lr: 0.0100
# Epoch 88/200
# 78/78 [==============================] - 25s 325ms/step - loss: 0.3535 - accuracy: 0.8813 - val_loss: 0.8491 - val_accuracy: 0.7627 - lr: 0.0100
# Epoch 89/200
# 78/78 [==============================] - 26s 329ms/step - loss: 0.3450 - accuracy: 0.8827 - val_loss: 0.7687 - val_accuracy: 0.8080 - lr: 0.0100
# Epoch 90/200
# 78/78 [==============================] - 24s 313ms/step - loss: 0.3469 - accuracy: 0.8825 - val_loss: 0.5648 - val_accuracy: 0.8394 - lr: 0.0100
# Epoch 91/200
# 78/78 [==============================] - 31s 393ms/step - loss: 0.3471 - accuracy: 0.8816 - val_loss: 0.4977 - val_accuracy: 0.8472 - lr: 0.0100
# Epoch 92/200
# 78/78 [==============================] - 27s 345ms/step - loss: 0.3383 - accuracy: 0.8851 - val_loss: 0.6313 - val_accuracy: 0.8402 - lr: 0.0100
# Epoch 93/200
# 78/78 [==============================] - 25s 324ms/step - loss: 0.3379 - accuracy: 0.8859 - val_loss: 0.6084 - val_accuracy: 0.8413 - lr: 0.0100
# Epoch 94/200
# 78/78 [==============================] - 26s 326ms/step - loss: 0.3244 - accuracy: 0.8901 - val_loss: 0.6982 - val_accuracy: 0.8041 - lr: 0.0100
# Epoch 95/200
# 78/78 [==============================] - 26s 335ms/step - loss: 0.3438 - accuracy: 0.8823 - val_loss: 0.5671 - val_accuracy: 0.8335 - lr: 0.0100
# Epoch 96/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.3271 - accuracy: 0.8878 - val_loss: 0.6197 - val_accuracy: 0.8184 - lr: 0.0100
# Epoch 97/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.3241 - accuracy: 0.8906 - val_loss: 0.5414 - val_accuracy: 0.8452 - lr: 0.0100
# Epoch 98/200
# 78/78 [==============================] - 26s 334ms/step - loss: 0.3197 - accuracy: 0.8917 - val_loss: 0.6472 - val_accuracy: 0.8218 - lr: 0.0100
# Epoch 99/200
# 78/78 [==============================] - 26s 338ms/step - loss: 0.3167 - accuracy: 0.8927 - val_loss: 0.6726 - val_accuracy: 0.8214 - lr: 0.0100
# Epoch 100/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.3075 - accuracy: 0.8952 - val_loss: 0.6083 - val_accuracy: 0.8274 - lr: 0.0100
# Epoch 101/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.3107 - accuracy: 0.8942 - val_loss: 0.5894 - val_accuracy: 0.8373 - lr: 0.0100
# Epoch 102/200
# 78/78 [==============================] - 27s 345ms/step - loss: 0.3062 - accuracy: 0.8960 - val_loss: 0.5728 - val_accuracy: 0.8380 - lr: 0.0100
# Epoch 103/200
# 78/78 [==============================] - 27s 342ms/step - loss: 0.2984 - accuracy: 0.8974 - val_loss: 0.6167 - val_accuracy: 0.8309 - lr: 0.0100
# Epoch 104/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.2886 - accuracy: 0.9011 - val_loss: 0.6124 - val_accuracy: 0.8260 - lr: 0.0100
# Epoch 105/200
# 78/78 [==============================] - 27s 342ms/step - loss: 0.2978 - accuracy: 0.8997 - val_loss: 0.6082 - val_accuracy: 0.8468 - lr: 0.0100
# Epoch 106/200
# 78/78 [==============================] - 27s 343ms/step - loss: 0.2924 - accuracy: 0.9005 - val_loss: 0.6088 - val_accuracy: 0.8350 - lr: 0.0100
# Epoch 107/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.2849 - accuracy: 0.9026 - val_loss: 0.5612 - val_accuracy: 0.8374 - lr: 0.0100
# Epoch 108/200
# 78/78 [==============================] - 26s 335ms/step - loss: 0.2743 - accuracy: 0.9073 - val_loss: 0.6174 - val_accuracy: 0.8269 - lr: 0.0100
# Epoch 109/200
# 78/78 [==============================] - 26s 327ms/step - loss: 0.2956 - accuracy: 0.9001 - val_loss: 0.7069 - val_accuracy: 0.8260 - lr: 0.0100
# Epoch 110/200
# 78/78 [==============================] - 26s 335ms/step - loss: 0.2778 - accuracy: 0.9065 - val_loss: 0.6500 - val_accuracy: 0.8312 - lr: 0.0100
# Epoch 111/200
# 78/78 [==============================] - 25s 326ms/step - loss: 0.2773 - accuracy: 0.9064 - val_loss: 0.7404 - val_accuracy: 0.8212 - lr: 0.0100
# Epoch 112/200
# 78/78 [==============================] - 30s 387ms/step - loss: 0.2168 - accuracy: 0.9263 - val_loss: 0.5652 - val_accuracy: 0.8617 - lr: 1.0000e-03
# Epoch 113/200
# 78/78 [==============================] - 30s 386ms/step - loss: 0.1977 - accuracy: 0.9323 - val_loss: 0.5523 - val_accuracy: 0.8619 - lr: 1.0000e-03
# Epoch 114/200
# 78/78 [==============================] - 31s 393ms/step - loss: 0.1869 - accuracy: 0.9368 - val_loss: 0.5293 - val_accuracy: 0.8654 - lr: 1.0000e-03
# Epoch 115/200
# 78/78 [==============================] - 27s 343ms/step - loss: 0.1872 - accuracy: 0.9350 - val_loss: 0.5295 - val_accuracy: 0.8609 - lr: 1.0000e-03
# Epoch 116/200
# 78/78 [==============================] - 26s 330ms/step - loss: 0.1797 - accuracy: 0.9388 - val_loss: 0.5341 - val_accuracy: 0.8620 - lr: 1.0000e-03
# Epoch 117/200
# 78/78 [==============================] - 30s 390ms/step - loss: 0.1767 - accuracy: 0.9390 - val_loss: 0.5089 - val_accuracy: 0.8672 - lr: 1.0000e-03
# Epoch 118/200
# 78/78 [==============================] - 26s 328ms/step - loss: 0.1743 - accuracy: 0.9411 - val_loss: 0.4995 - val_accuracy: 0.8631 - lr: 1.0000e-03
# Epoch 119/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.1689 - accuracy: 0.9435 - val_loss: 0.4865 - val_accuracy: 0.8659 - lr: 1.0000e-03
# Epoch 120/200
# 78/78 [==============================] - 26s 327ms/step - loss: 0.1711 - accuracy: 0.9409 - val_loss: 0.4949 - val_accuracy: 0.8656 - lr: 1.0000e-03
# Epoch 121/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.1717 - accuracy: 0.9420 - val_loss: 0.4997 - val_accuracy: 0.8616 - lr: 1.0000e-03
# Epoch 122/200
# 78/78 [==============================] - 26s 332ms/step - loss: 0.1617 - accuracy: 0.9453 - val_loss: 0.5077 - val_accuracy: 0.8626 - lr: 1.0000e-03
# Epoch 123/200
# 78/78 [==============================] - 26s 336ms/step - loss: 0.1683 - accuracy: 0.9426 - val_loss: 0.5041 - val_accuracy: 0.8651 - lr: 1.0000e-03
# Epoch 124/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.1631 - accuracy: 0.9457 - val_loss: 0.5044 - val_accuracy: 0.8640 - lr: 1.0000e-03
# Epoch 125/200
# 78/78 [==============================] - 27s 340ms/step - loss: 0.1626 - accuracy: 0.9450 - val_loss: 0.5056 - val_accuracy: 0.8658 - lr: 1.0000e-03
# Epoch 126/200
# 78/78 [==============================] - 26s 334ms/step - loss: 0.1616 - accuracy: 0.9447 - val_loss: 0.5226 - val_accuracy: 0.8610 - lr: 1.0000e-03
# Epoch 127/200
# 78/78 [==============================] - 26s 338ms/step - loss: 0.1582 - accuracy: 0.9456 - val_loss: 0.5120 - val_accuracy: 0.8636 - lr: 1.0000e-03
# Epoch 128/200
# 78/78 [==============================] - 25s 329ms/step - loss: 0.1571 - accuracy: 0.9471 - val_loss: 0.5364 - val_accuracy: 0.8577 - lr: 1.0000e-03
# Epoch 129/200
# 78/78 [==============================] - 26s 333ms/step - loss: 0.1597 - accuracy: 0.9459 - val_loss: 0.5208 - val_accuracy: 0.8632 - lr: 1.0000e-03
# Epoch 130/200
# 78/78 [==============================] - 25s 320ms/step - loss: 0.1516 - accuracy: 0.9480 - val_loss: 0.5110 - val_accuracy: 0.8658 - lr: 1.0000e-03
# Epoch 131/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.1529 - accuracy: 0.9481 - val_loss: 0.5231 - val_accuracy: 0.8654 - lr: 1.0000e-03
# Epoch 132/200
# 78/78 [==============================] - 26s 332ms/step - loss: 0.1527 - accuracy: 0.9485 - val_loss: 0.5530 - val_accuracy: 0.8614 - lr: 1.0000e-03
# Epoch 133/200
# 78/78 [==============================] - 26s 333ms/step - loss: 0.1466 - accuracy: 0.9508 - val_loss: 0.5260 - val_accuracy: 0.8670 - lr: 1.0000e-03
# Epoch 134/200
# 78/78 [==============================] - 26s 332ms/step - loss: 0.1511 - accuracy: 0.9491 - val_loss: 0.5625 - val_accuracy: 0.8597 - lr: 1.0000e-03
# Epoch 135/200
# 78/78 [==============================] - 25s 320ms/step - loss: 0.1491 - accuracy: 0.9491 - val_loss: 0.5459 - val_accuracy: 0.8660 - lr: 1.0000e-03
# Epoch 136/200
# 78/78 [==============================] - 26s 337ms/step - loss: 0.1440 - accuracy: 0.9516 - val_loss: 0.5858 - val_accuracy: 0.8634 - lr: 1.0000e-03
# Epoch 137/200
# 78/78 [==============================] - 26s 330ms/step - loss: 0.1477 - accuracy: 0.9498 - val_loss: 0.6135 - val_accuracy: 0.8620 - lr: 1.0000e-03
# Epoch 138/200
# 78/78 [==============================] - 26s 326ms/step - loss: 0.1474 - accuracy: 0.9503 - val_loss: 0.5110 - val_accuracy: 0.8643 - lr: 1.0000e-03
# Epoch 139/200
# 78/78 [==============================] - 27s 338ms/step - loss: 0.1454 - accuracy: 0.9507 - val_loss: 0.5184 - val_accuracy: 0.8639 - lr: 1.0000e-03
# Epoch 140/200
# 78/78 [==============================] - 27s 341ms/step - loss: 0.1410 - accuracy: 0.9523 - val_loss: 0.5104 - val_accuracy: 0.8668 - lr: 1.0000e-04
# Epoch 141/200
# 78/78 [==============================] - 27s 346ms/step - loss: 0.1379 - accuracy: 0.9530 - val_loss: 0.5144 - val_accuracy: 0.8671 - lr: 1.0000e-04
# Epoch 142/200
# 78/78 [==============================] - 31s 398ms/step - loss: 0.1377 - accuracy: 0.9538 - val_loss: 0.5099 - val_accuracy: 0.8673 - lr: 1.0000e-04
# Epoch 143/200
# 78/78 [==============================] - 28s 361ms/step - loss: 0.1375 - accuracy: 0.9539 - val_loss: 0.5104 - val_accuracy: 0.8670 - lr: 1.0000e-04
# Epoch 144/200
# 78/78 [==============================] - 27s 351ms/step - loss: 0.1402 - accuracy: 0.9520 - val_loss: 0.5146 - val_accuracy: 0.8668 - lr: 1.0000e-04
# Epoch 145/200
# 78/78 [==============================] - 27s 346ms/step - loss: 0.1353 - accuracy: 0.9538 - val_loss: 0.5164 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 146/200
# 78/78 [==============================] - 27s 344ms/step - loss: 0.1360 - accuracy: 0.9533 - val_loss: 0.5141 - val_accuracy: 0.8669 - lr: 1.0000e-04
# Epoch 147/200
# 78/78 [==============================] - 27s 346ms/step - loss: 0.1375 - accuracy: 0.9535 - val_loss: 0.5179 - val_accuracy: 0.8666 - lr: 1.0000e-04
# Epoch 148/200
# 78/78 [==============================] - 27s 347ms/step - loss: 0.1373 - accuracy: 0.9541 - val_loss: 0.5186 - val_accuracy: 0.8670 - lr: 1.0000e-04
# Epoch 149/200
# 78/78 [==============================] - 27s 349ms/step - loss: 0.1309 - accuracy: 0.9562 - val_loss: 0.5251 - val_accuracy: 0.8669 - lr: 1.0000e-04

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 1:18:50.708430

# %% [markdown]
# Cargo el mejor model que he guardado con el ModelCheckpoint.

# %%
model = ks.models.load_model(checkpoint_path)

# %% [markdown]
# ## 9. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 85.910

# %%
# elimino el primer valor de val_loss para no distorsionar el grafico de loss, en cuanto el error a la prima iteración es muy alto
# comparado con los demás.
first_val_loss = history.history['val_loss'].pop(0)

# %%
first_val_loss
# Out:
# 87.52840423583984

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 10. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Entregables/Entregable_04-Deep_Learning/Models/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_model_12.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
