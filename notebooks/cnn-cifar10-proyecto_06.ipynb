# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## **MASTER DATA SCIENCE:** Nuclio
# ## **PROFESORES:** Valentina Borgonovi, Isidre Royo
# ## **ENTREGABLE 4:** Deep Learning - Visión por computador
# ## **ALUMNO:** Simone Solieri

# %% [markdown]
# ## **Proyecto 6** - Resumen
# **Objetivo:** Eliminar overfitting y llegar al objetivo del 80% de accuracy en test
#
# **Cambios efectuados:**
# - l2 regularitazion con SGD optimizer y momentum
# - dropout a 0.5
#
#  **Resultados**:
# Resultados esperados: mejora del accuracy de test
#
# Resultados obtenidos:

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()
model.add(ks.layers.Conv2D(32, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu', kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1,
          activation='relu',kernel_regularizer=l2(0.01),
          padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(256,
          activation='relu',kernel_regularizer=l2(0.01)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_6 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 965034 (3.68 MB)
# Trainable params: 963370 (3.67 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer= SGD(learning_rate=0.01, momentum=0.9),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 32x32 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset Cifar10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 512
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# # EarlyStopping
earlystop_val_acc = EarlyStopping(monitor='val_accuracy', patience=50)
earlystop_val_loss = EarlyStopping(monitor='val_loss', patience=10)

reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=5, min_lr=0.00001, )

# ModelCheckpoint
checkpoint_path = '/content/drive/MyDrive/Master_Data_Science/Entregables/Entregable_04-Deep_Learning/Models/Model_Checkpoints/Best_accuracy_proyecto_6'
modelcheckpoint_best_acc = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True)

# %%
history = model.fit(x_train_scaled, y_train,
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val),
                    callbacks=[modelcheckpoint_best_acc, reduce_lr_callback, earlystop_val_loss, earlystop_val_acc ])
# Out:
# Epoch 1/300
# 79/79 [==============================] - 24s 176ms/step - loss: 10.8516 - accuracy: 0.2731 - val_loss: 10.0232 - val_accuracy: 0.1003 - lr: 0.0100
# Epoch 2/300
# 79/79 [==============================] - 11s 136ms/step - loss: 7.9665 - accuracy: 0.4145 - val_loss: 8.0509 - val_accuracy: 0.1035 - lr: 0.0100
# Epoch 3/300
# 79/79 [==============================] - 6s 80ms/step - loss: 6.0603 - accuracy: 0.4776 - val_loss: 6.9505 - val_accuracy: 0.1033 - lr: 0.0100
# Epoch 4/300
# 79/79 [==============================] - 10s 130ms/step - loss: 4.6715 - accuracy: 0.5378 - val_loss: 6.0508 - val_accuracy: 0.1425 - lr: 0.0100
# Epoch 5/300
# 79/79 [==============================] - 11s 135ms/step - loss: 3.6587 - accuracy: 0.5839 - val_loss: 5.0028 - val_accuracy: 0.1879 - lr: 0.0100
# Epoch 6/300
# 79/79 [==============================] - 6s 82ms/step - loss: 2.9305 - accuracy: 0.6205 - val_loss: 4.5808 - val_accuracy: 0.1791 - lr: 0.0100
# Epoch 7/300
# 79/79 [==============================] - 9s 119ms/step - loss: 2.3941 - accuracy: 0.6468 - val_loss: 4.3392 - val_accuracy: 0.2037 - lr: 0.0100
# Epoch 8/300
# 79/79 [==============================] - 11s 135ms/step - loss: 2.0094 - accuracy: 0.6698 - val_loss: 3.7551 - val_accuracy: 0.2449 - lr: 0.0100
# Epoch 9/300
# 79/79 [==============================] - 9s 119ms/step - loss: 1.7236 - accuracy: 0.6892 - val_loss: 2.5318 - val_accuracy: 0.3916 - lr: 0.0100
# Epoch 10/300
# 79/79 [==============================] - 10s 123ms/step - loss: 1.5138 - accuracy: 0.7056 - val_loss: 2.0376 - val_accuracy: 0.5123 - lr: 0.0100
# Epoch 11/300
# 79/79 [==============================] - 10s 121ms/step - loss: 1.3599 - accuracy: 0.7226 - val_loss: 1.6302 - val_accuracy: 0.5985 - lr: 0.0100
# Epoch 12/300
# 79/79 [==============================] - 6s 81ms/step - loss: 1.2664 - accuracy: 0.7311 - val_loss: 1.6312 - val_accuracy: 0.5969 - lr: 0.0100
# Epoch 13/300
# 79/79 [==============================] - 6s 82ms/step - loss: 1.1816 - accuracy: 0.7439 - val_loss: 2.2720 - val_accuracy: 0.4053 - lr: 0.0100
# Epoch 14/300
# 79/79 [==============================] - 10s 131ms/step - loss: 1.1323 - accuracy: 0.7485 - val_loss: 1.2875 - val_accuracy: 0.6960 - lr: 0.0100
# Epoch 15/300
# 79/79 [==============================] - 6s 81ms/step - loss: 1.0948 - accuracy: 0.7541 - val_loss: 1.3617 - val_accuracy: 0.6676 - lr: 0.0100
# Epoch 16/300
# 79/79 [==============================] - 6s 81ms/step - loss: 1.0550 - accuracy: 0.7620 - val_loss: 1.6323 - val_accuracy: 0.6013 - lr: 0.0100
# Epoch 17/300
# 79/79 [==============================] - 6s 81ms/step - loss: 1.0400 - accuracy: 0.7652 - val_loss: 1.4768 - val_accuracy: 0.6308 - lr: 0.0100
# Epoch 18/300
# 79/79 [==============================] - 10s 126ms/step - loss: 1.0284 - accuracy: 0.7697 - val_loss: 1.0531 - val_accuracy: 0.7581 - lr: 0.0100
# Epoch 19/300
# 79/79 [==============================] - 6s 80ms/step - loss: 1.0153 - accuracy: 0.7751 - val_loss: 1.8518 - val_accuracy: 0.5459 - lr: 0.0100
# Epoch 20/300
# 79/79 [==============================] - 6s 82ms/step - loss: 1.0227 - accuracy: 0.7721 - val_loss: 1.9192 - val_accuracy: 0.5317 - lr: 0.0100
# Epoch 21/300
# 79/79 [==============================] - 10s 123ms/step - loss: 1.0018 - accuracy: 0.7786 - val_loss: 0.9955 - val_accuracy: 0.7827 - lr: 0.0100
# Epoch 22/300
# 79/79 [==============================] - 6s 81ms/step - loss: 1.0057 - accuracy: 0.7801 - val_loss: 1.6418 - val_accuracy: 0.6102 - lr: 0.0100
# Epoch 23/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.9923 - accuracy: 0.7857 - val_loss: 1.1756 - val_accuracy: 0.7372 - lr: 0.0100
# Epoch 24/300
# 79/79 [==============================] - 6s 82ms/step - loss: 1.0008 - accuracy: 0.7858 - val_loss: 2.0005 - val_accuracy: 0.5548 - lr: 0.0100
# Epoch 25/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.9923 - accuracy: 0.7884 - val_loss: 1.3517 - val_accuracy: 0.6779 - lr: 0.0100
# Epoch 26/300
# 79/79 [==============================] - 7s 84ms/step - loss: 0.9996 - accuracy: 0.7901 - val_loss: 1.0360 - val_accuracy: 0.7752 - lr: 0.0100
# Epoch 27/300
# 79/79 [==============================] - 9s 117ms/step - loss: 1.0374 - accuracy: 0.7809 - val_loss: 0.9919 - val_accuracy: 0.7954 - lr: 1.0000e-03
# Epoch 28/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.8824 - accuracy: 0.8295 - val_loss: 0.8637 - val_accuracy: 0.8343 - lr: 1.0000e-03
# Epoch 29/300
# 79/79 [==============================] - 10s 122ms/step - loss: 0.8278 - accuracy: 0.8431 - val_loss: 0.8253 - val_accuracy: 0.8412 - lr: 1.0000e-03
# Epoch 30/300
# 79/79 [==============================] - 10s 133ms/step - loss: 0.7947 - accuracy: 0.8533 - val_loss: 0.8080 - val_accuracy: 0.8449 - lr: 1.0000e-03
# Epoch 31/300
# 79/79 [==============================] - 10s 121ms/step - loss: 0.7681 - accuracy: 0.8595 - val_loss: 0.7833 - val_accuracy: 0.8490 - lr: 1.0000e-03
# Epoch 32/300
# 79/79 [==============================] - 9s 120ms/step - loss: 0.7422 - accuracy: 0.8631 - val_loss: 0.7671 - val_accuracy: 0.8521 - lr: 1.0000e-03
# Epoch 33/300
# 79/79 [==============================] - 10s 132ms/step - loss: 0.7220 - accuracy: 0.8680 - val_loss: 0.7558 - val_accuracy: 0.8539 - lr: 1.0000e-03
# Epoch 34/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.6990 - accuracy: 0.8744 - val_loss: 0.7746 - val_accuracy: 0.8440 - lr: 1.0000e-03
# Epoch 35/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.6832 - accuracy: 0.8758 - val_loss: 0.7324 - val_accuracy: 0.8513 - lr: 1.0000e-03
# Epoch 36/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.6646 - accuracy: 0.8776 - val_loss: 0.7292 - val_accuracy: 0.8512 - lr: 1.0000e-03
# Epoch 37/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.6512 - accuracy: 0.8797 - val_loss: 0.7313 - val_accuracy: 0.8511 - lr: 1.0000e-03
# Epoch 38/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.6366 - accuracy: 0.8810 - val_loss: 0.7450 - val_accuracy: 0.8438 - lr: 1.0000e-03
# Epoch 39/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.6229 - accuracy: 0.8857 - val_loss: 0.7443 - val_accuracy: 0.8435 - lr: 1.0000e-03
# Epoch 40/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.6042 - accuracy: 0.8870 - val_loss: 0.7353 - val_accuracy: 0.8434 - lr: 1.0000e-03
# Epoch 41/300
# 79/79 [==============================] - 9s 118ms/step - loss: 0.5959 - accuracy: 0.8898 - val_loss: 0.6848 - val_accuracy: 0.8583 - lr: 1.0000e-03
# Epoch 42/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5851 - accuracy: 0.8917 - val_loss: 0.6930 - val_accuracy: 0.8558 - lr: 1.0000e-03
# Epoch 43/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5723 - accuracy: 0.8919 - val_loss: 0.6883 - val_accuracy: 0.8535 - lr: 1.0000e-03
# Epoch 44/300
# 79/79 [==============================] - 10s 132ms/step - loss: 0.5598 - accuracy: 0.8957 - val_loss: 0.6624 - val_accuracy: 0.8596 - lr: 1.0000e-03
# Epoch 45/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.5500 - accuracy: 0.8972 - val_loss: 0.7047 - val_accuracy: 0.8472 - lr: 1.0000e-03
# Epoch 46/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.5426 - accuracy: 0.8982 - val_loss: 0.6519 - val_accuracy: 0.8595 - lr: 1.0000e-03
# Epoch 47/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5350 - accuracy: 0.8979 - val_loss: 0.6869 - val_accuracy: 0.8511 - lr: 1.0000e-03
# Epoch 48/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5258 - accuracy: 0.9000 - val_loss: 0.6732 - val_accuracy: 0.8527 - lr: 1.0000e-03
# Epoch 49/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5224 - accuracy: 0.8997 - val_loss: 0.6707 - val_accuracy: 0.8519 - lr: 1.0000e-03
# Epoch 50/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5146 - accuracy: 0.9006 - val_loss: 0.6733 - val_accuracy: 0.8493 - lr: 1.0000e-03
# Epoch 51/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.5081 - accuracy: 0.9014 - val_loss: 0.6727 - val_accuracy: 0.8488 - lr: 1.0000e-03
# Epoch 52/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.5106 - accuracy: 0.9006 - val_loss: 0.6500 - val_accuracy: 0.8587 - lr: 1.0000e-04
# Epoch 53/300
# 79/79 [==============================] - 10s 128ms/step - loss: 0.4676 - accuracy: 0.9176 - val_loss: 0.6371 - val_accuracy: 0.8626 - lr: 1.0000e-04
# Epoch 54/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.4589 - accuracy: 0.9196 - val_loss: 0.6279 - val_accuracy: 0.8647 - lr: 1.0000e-04
# Epoch 55/300
# 79/79 [==============================] - 10s 129ms/step - loss: 0.4535 - accuracy: 0.9204 - val_loss: 0.6205 - val_accuracy: 0.8676 - lr: 1.0000e-04
# Epoch 56/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.4484 - accuracy: 0.9225 - val_loss: 0.6226 - val_accuracy: 0.8671 - lr: 1.0000e-04
# Epoch 57/300
# 79/79 [==============================] - 10s 124ms/step - loss: 0.4445 - accuracy: 0.9241 - val_loss: 0.6158 - val_accuracy: 0.8681 - lr: 1.0000e-04
# Epoch 58/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4430 - accuracy: 0.9237 - val_loss: 0.6187 - val_accuracy: 0.8673 - lr: 1.0000e-04
# Epoch 59/300
# 79/79 [==============================] - 9s 119ms/step - loss: 0.4392 - accuracy: 0.9252 - val_loss: 0.6191 - val_accuracy: 0.8690 - lr: 1.0000e-04
# Epoch 60/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.4314 - accuracy: 0.9283 - val_loss: 0.6139 - val_accuracy: 0.8684 - lr: 1.0000e-04
# Epoch 61/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4295 - accuracy: 0.9275 - val_loss: 0.6178 - val_accuracy: 0.8680 - lr: 1.0000e-04
# Epoch 62/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4296 - accuracy: 0.9285 - val_loss: 0.6153 - val_accuracy: 0.8681 - lr: 1.0000e-04
# Epoch 63/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4283 - accuracy: 0.9278 - val_loss: 0.6208 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 64/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4260 - accuracy: 0.9279 - val_loss: 0.6136 - val_accuracy: 0.8680 - lr: 1.0000e-04
# Epoch 65/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4224 - accuracy: 0.9298 - val_loss: 0.6110 - val_accuracy: 0.8685 - lr: 1.0000e-04
# Epoch 66/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4209 - accuracy: 0.9306 - val_loss: 0.6133 - val_accuracy: 0.8679 - lr: 1.0000e-04
# Epoch 67/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4159 - accuracy: 0.9303 - val_loss: 0.6179 - val_accuracy: 0.8680 - lr: 1.0000e-04
# Epoch 68/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4132 - accuracy: 0.9330 - val_loss: 0.6196 - val_accuracy: 0.8670 - lr: 1.0000e-04
# Epoch 69/300
# 79/79 [==============================] - 10s 123ms/step - loss: 0.4087 - accuracy: 0.9331 - val_loss: 0.6107 - val_accuracy: 0.8702 - lr: 1.0000e-04
# Epoch 70/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.4089 - accuracy: 0.9330 - val_loss: 0.6115 - val_accuracy: 0.8666 - lr: 1.0000e-04
# Epoch 71/300
# 79/79 [==============================] - 9s 118ms/step - loss: 0.4096 - accuracy: 0.9334 - val_loss: 0.6130 - val_accuracy: 0.8703 - lr: 1.0000e-04
# Epoch 72/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.4097 - accuracy: 0.9336 - val_loss: 0.6154 - val_accuracy: 0.8686 - lr: 1.0000e-04
# Epoch 73/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.4041 - accuracy: 0.9352 - val_loss: 0.6177 - val_accuracy: 0.8650 - lr: 1.0000e-04
# Epoch 74/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.4016 - accuracy: 0.9357 - val_loss: 0.6139 - val_accuracy: 0.8674 - lr: 1.0000e-04
# Epoch 75/300
# 79/79 [==============================] - 10s 129ms/step - loss: 0.4012 - accuracy: 0.9345 - val_loss: 0.6091 - val_accuracy: 0.8708 - lr: 1.0000e-05
# Epoch 76/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3989 - accuracy: 0.9370 - val_loss: 0.6084 - val_accuracy: 0.8694 - lr: 1.0000e-05
# Epoch 77/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3955 - accuracy: 0.9364 - val_loss: 0.6080 - val_accuracy: 0.8702 - lr: 1.0000e-05
# Epoch 78/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3994 - accuracy: 0.9360 - val_loss: 0.6080 - val_accuracy: 0.8700 - lr: 1.0000e-05
# Epoch 79/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3982 - accuracy: 0.9371 - val_loss: 0.6086 - val_accuracy: 0.8705 - lr: 1.0000e-05
# Epoch 80/300
# 79/79 [==============================] - 7s 82ms/step - loss: 0.3966 - accuracy: 0.9369 - val_loss: 0.6076 - val_accuracy: 0.8704 - lr: 1.0000e-05
# Epoch 81/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3983 - accuracy: 0.9356 - val_loss: 0.6078 - val_accuracy: 0.8695 - lr: 1.0000e-05
# Epoch 82/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3964 - accuracy: 0.9362 - val_loss: 0.6070 - val_accuracy: 0.8699 - lr: 1.0000e-05
# Epoch 83/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3961 - accuracy: 0.9367 - val_loss: 0.6082 - val_accuracy: 0.8700 - lr: 1.0000e-05
# Epoch 84/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3968 - accuracy: 0.9367 - val_loss: 0.6079 - val_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 85/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3955 - accuracy: 0.9359 - val_loss: 0.6078 - val_accuracy: 0.8702 - lr: 1.0000e-05
# Epoch 86/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3964 - accuracy: 0.9380 - val_loss: 0.6088 - val_accuracy: 0.8707 - lr: 1.0000e-05
# Epoch 87/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3968 - accuracy: 0.9352 - val_loss: 0.6077 - val_accuracy: 0.8703 - lr: 1.0000e-05
# Epoch 88/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3944 - accuracy: 0.9378 - val_loss: 0.6086 - val_accuracy: 0.8697 - lr: 1.0000e-05
# Epoch 89/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3927 - accuracy: 0.9388 - val_loss: 0.6078 - val_accuracy: 0.8689 - lr: 1.0000e-05
# Epoch 90/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3964 - accuracy: 0.9359 - val_loss: 0.6071 - val_accuracy: 0.8699 - lr: 1.0000e-05
# Epoch 91/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3941 - accuracy: 0.9380 - val_loss: 0.6064 - val_accuracy: 0.8701 - lr: 1.0000e-05
# Epoch 92/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3935 - accuracy: 0.9376 - val_loss: 0.6068 - val_accuracy: 0.8703 - lr: 1.0000e-05
# Epoch 93/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3908 - accuracy: 0.9394 - val_loss: 0.6075 - val_accuracy: 0.8698 - lr: 1.0000e-05
# Epoch 94/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3918 - accuracy: 0.9394 - val_loss: 0.6083 - val_accuracy: 0.8699 - lr: 1.0000e-05
# Epoch 95/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3912 - accuracy: 0.9391 - val_loss: 0.6075 - val_accuracy: 0.8689 - lr: 1.0000e-05
# Epoch 96/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3932 - accuracy: 0.9380 - val_loss: 0.6074 - val_accuracy: 0.8690 - lr: 1.0000e-05
# Epoch 97/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3897 - accuracy: 0.9391 - val_loss: 0.6074 - val_accuracy: 0.8697 - lr: 1.0000e-05
# Epoch 98/300
# 79/79 [==============================] - 6s 82ms/step - loss: 0.3891 - accuracy: 0.9400 - val_loss: 0.6064 - val_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 99/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3946 - accuracy: 0.9366 - val_loss: 0.6075 - val_accuracy: 0.8698 - lr: 1.0000e-05
# Epoch 100/300
# 79/79 [==============================] - 6s 81ms/step - loss: 0.3920 - accuracy: 0.9366 - val_loss: 0.6068 - val_accuracy: 0.8700 - lr: 1.0000e-05
# Epoch 101/300
# 79/79 [==============================] - 6s 80ms/step - loss: 0.3904 - accuracy: 0.9386 - val_loss: 0.6077 - val_accuracy: 0.8701 - lr: 1.0000e-05

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:12:44.584543

# %% [markdown]
# Cargo el mejor model que he guardado con el ModelCheckpoint.

# %%
model = ks.models.load_model(checkpoint_path)

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 86.970

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Entregables/Entregable_04-Deep_Learning/Models/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_model_6.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
